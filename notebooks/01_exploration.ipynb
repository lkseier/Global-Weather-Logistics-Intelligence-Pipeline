# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

# Load your .env file
load_dotenv('../.env') # Note the '../' because the notebook is inside a folder

api_key = os.getenv("WEATHER_API_KEY")
CITY = "Brussels"  # You can change this to any city
URL = f"http://api.openweathermap.org/data/2.5/weather?q={CITY}&appid={api_key}&units=metric"

print(f"API Key loaded: {api_key is not None}")
# Out:
# API Key loaded: True

# %%
response = requests.get(URL)
data = response.json()

# This lets you see exactly what the API is sending back
data
# Out:
# {'coord': {'lon': 4.3488, 'lat': 50.8504},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 16.14,
#   'feels_like': 15.22,
#   'temp_min': 14.9,
#   'temp_max': 17.17,
#   'pressure': 1023,
#   'humidity': 54,
#   'sea_level': 1023,
#   'grnd_level': 1016},
#  'visibility': 10000,
#  'wind': {'speed': 4.63, 'deg': 340},
#  'clouds': {'all': 20},
#  'dt': 1776604501,
#  'sys': {'type': 1,
#   'id': 1227,
#   'country': 'BE',
#   'sunrise': 1776573600,
#   'sunset': 1776624186},
#  'timezone': 7200,
#  'id': 2800866,
#  'name': 'Brussels',
#  'cod': 200}

# %%
# Create a simple DataFrame from the specific fields we want
df = pd.DataFrame([{
    "city": data["name"],
    "temp": data["main"]["temp"],
    "description": data["weather"][0]["description"],
    "timestamp": pd.to_datetime(data["dt"], unit='s')
}])

df.head()
# Out:
#        city   temp description           timestamp
# 0  Brussels  16.14  few clouds 2026-04-19 13:15:01
